# %%
# %config Completer.use_jedi = False
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rc
rc('font', family='Arial Unicode MS')
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False

import folium
import json
from glob import glob
import missingno as msno

## float format 설정
## exponential to numeric (지수를 숫자로)
pd.options.display.float_format = '{:.2f}'.format
## 다시 지수 방식으로
# pd.reset_option('^display.', silent=True)

# %% [markdown]
# ## 1. 데이터 임포트

# %% [markdown]
# - 시장규모

# %%
# Market size data 불러오기
df = pd.read_csv('./datas/market_size_reform.csv', encoding='utf-8')
df_ms = pd.DataFrame(df)
df_ms.head()
# Out:
#      년도        시장규모 산업분류
# 0  1995   855409035   전체
# 1  2000  1395749584   전체
# 2  2005  2058128879   전체
# 3  2006  2203889676   전체
# 4  2007  2396507678   전체

# %%
df_ms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      352 non-null    int64
#  1   시장규모    352 non-null    int64
#  2   산업분류    352 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 8.4+ KB

# %% [markdown]
# - 시총

# %%
# Market capitalization data 불러오기
df = pd.read_csv('./datas/mcz_by_industry_reform.csv', encoding='euc-kr')
df_mc = pd.DataFrame(df).drop(columns='Unnamed: 0')
df_mc.head()
# Out:
#      년도         산업분류      시총
# 0  2004  농업, 임업 및 어업  195279
# 1  2005  농업, 임업 및 어업  243346
# 2  2006  농업, 임업 및 어업  269164
# 3  2007  농업, 임업 및 어업  735154
# 4  2008  농업, 임업 및 어업  702432

# %%
df_mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      336 non-null    int64
#  1   산업분류    336 non-null    object
#  2   시총      336 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 8.0+ KB

# %% [markdown]
# - 매출

# %%
# Market Income data 불러오기
df = pd.read_csv('./datas/revenue_total.csv', encoding='utf-8')
df_mi = pd.DataFrame(df).rename(columns={'산업':'산업분류'})
df_mi.head()
# Out:
#   산업분류    년도  회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 0  건설업  2004       56   37431491      1531674     2719852     2181880
# 1  건설업  2005       54   40785394      2029565     3096864     2885231
# 2  건설업  2006       57   44745972      2755247     3657870     3652228
# 3  건설업  2007       57   47834524      2802313     3566035     3718370
# 4  건설업  2008       56   53570702      3195413     3672975     4577360
#
#    매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 0       13.81        4.08        29.86          5.66        11.85
# 1        3.67        4.96        36.71          6.78        13.24
# 2       12.41        5.85        46.30          7.95        14.79
# 3        5.07        4.87        38.70          6.54        11.28
# 4       16.48        4.12        37.41          6.09         9.69
#
#    총자본경상이익률 (%)
# 0          6.81
# 1          7.92
# 2          8.86
# 3          6.45
# 4          5.47

# %%
df_mi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   산업분류          352 non-null    object
#  1   년도            352 non-null    int64
#  2   회사수 (개)       352 non-null    int64
#  3   매출액 (백만원)     352 non-null    int64
#  4   당기순이익 (백만원)   352 non-null    int64
#  5   영업이익 (백만원)    352 non-null    int64
#  6   경상이익 (백만원)    352 non-null    int64
#  7   매출액증가율 (%)    352 non-null    float64
#  8   매출액이익률 (%)    352 non-null    float64
#  9   납입자본이익률 (%)   352 non-null    float64
#  10  매출액경상이익률 (%)  352 non-null    float64
#  11  자기자본이익률 (%)   352 non-null    float64
#  12  총자본경상이익률 (%)  352 non-null    float64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 35.9+ KB

# %% [markdown]
# ## 2. 비교

# %%
print(df_ms.shape, df_mc.shape, df_mi.shape)
print(len(df_ms), len(df_mc), len(df_mi))
# Out:
# (352, 3) (336, 3) (352, 13)
# 352 336 352

# %%
print(df_ms['년도'].unique())
print(df_mc['년도'].unique())
print(df_mi['년도'].unique())
print(df_ms['산업분류'].unique())
print(df_mc['산업분류'].unique())
print(df_mi['산업분류'].unique())
# Out:
# [1995 2000 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016
#  2017 2018]
# [2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019]
# [2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019]
# ['전체' '농업, 임업 및 어업' '광업' '제조업' '음식료품' '섬유의복' '종이·목재' '화학' '의약품' '비금속광물'
#  '철강금속' '기계' '전기전자' '의료·정밀기기' '운수장비' '기타제조업' '유통업' '전기가스' '건설업' '운수창고업'
#  '통신업' '서비스업']
# ['농업, 임업 및 어업' '광업' '제조업' '음식료품' '섬유의복' '종이·목재' '화학' '의약품' '비금속광물' '철강금속'
#  '기계' '전기전자' '의료·정밀기기' '운수장비' '기타제조업' '유통업' '전기가스' '건설업' '운수창고업' '통신업'
#  '서비스업']
# ['건설업' '광업' '기계' '기타제조업' '농업, 임업 및 어업' '비금속광물' '서비스업' '섬유의복' '운수장비'
#  '운수창고업' '유통업' '음식료품' '의료·정밀기기' '의약품' '전기가스' '전기전자' '전체' '종이·목재' '철강금속'
#  '통신업' '화학' '제조업']

# %%
df1 = pd.DataFrame(df_ms['산업분류'].unique())
df2 = pd.DataFrame(df_mc['산업분류'].unique())
df3 = pd.DataFrame(df_mi['산업분류'].unique())

# %%
## df 2에는 '전체' 없다, df1 == df3
checker = df2.merge(df3, how='outer', suffixes=['', '_'], indicator=True)
checker
# Out:
#               0      _merge
# 0   농업, 임업 및 어업        both
# 1            광업        both
# 2           제조업        both
# 3          음식료품        both
# 4          섬유의복        both
# 5         종이·목재        both
# 6            화학        both
# 7           의약품        both
# 8         비금속광물        both
# 9          철강금속        both
# 10           기계        both
# 11         전기전자        both
# 12      의료·정밀기기        both
# 13         운수장비        both
# 14        기타제조업        both
# 15          유통업        both
# 16         전기가스        both
# 17          건설업        both
# 18        운수창고업        both
# 19          통신업        both
# 20         서비스업        both
# 21           전체  right_only

# %%
df1 = pd.DataFrame(df_ms['년도'].unique())
df2 = pd.DataFrame(df_mc['년도'].unique())
df3 = pd.DataFrame(df_mi['년도'].unique())

# %%
checker = df3.merge(df2, how='outer', suffixes=['', '_'], indicator=True)
checker
## 1995, 2000은 df1 에만, 2004 2019는 df2에만 , df2 == df3
# Out:
#        0 _merge
# 0   2004   both
# 1   2005   both
# 2   2006   both
# 3   2007   both
# 4   2008   both
# 5   2009   both
# 6   2010   both
# 7   2011   both
# 8   2012   both
# 9   2013   both
# 10  2014   both
# 11  2015   both
# 12  2016   both
# 13  2017   both
# 14  2018   both
# 15  2019   both

# %% [markdown]
# ## 3. 합치기

# %%
# MS / MC DataFrame 합치기
df_msmc = pd.merge(df_ms, df_mc, how='outer', on=['산업분류','년도'])
df_msmc = df_msmc[['산업분류', '년도', '시장규모', '시총']]
df_msmc.head()
# Out:
#   산업분류    년도          시장규모  시총
# 0   전체  1995  855409035.00 nan
# 1   전체  2000 1395749584.00 nan
# 2   전체  2005 2058128879.00 nan
# 3   전체  2006 2203889676.00 nan
# 4   전체  2007 2396507678.00 nan

# %%
df_msmc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394 entries, 0 to 393
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   산업분류    394 non-null    object
#  1   년도      394 non-null    int64
#  2   시장규모    352 non-null    float64
#  3   시총      336 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.4+ KB

# %%
df_msmc.loc[df_msmc['시장규모'].isnull(),'년도'].unique()
# Out:
# array([2004, 2019])

# %%
industry_df = pd.merge(df_mi, df_msmc, on=['산업분류','년도'], how='outer')
industry_df
# Out:
#       산업분류    년도  회사수 (개)   매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 0      건설업  2004    56.00 37431491.00   1531674.00  2719852.00  2181880.00
# 1      건설업  2005    54.00 40785394.00   2029565.00  3096864.00  2885231.00
# 2      건설업  2006    57.00 44745972.00   2755247.00  3657870.00  3652228.00
# 3      건설업  2007    57.00 47834524.00   2802313.00  3566035.00  3718370.00
# 4      건설업  2008    56.00 53570702.00   3195413.00  3672975.00  4577360.00
# ..     ...   ...      ...         ...          ...         ...         ...
# 391  운수창고업  2000      nan         nan          nan         nan         nan
# 392    통신업  1995      nan         nan          nan         nan         nan
# 393    통신업  2000      nan         nan          nan         nan         nan
# 394   서비스업  1995      nan         nan          nan         nan         nan
# 395   서비스업  2000      nan         nan          nan         nan         nan
#
#      매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 0         13.81        4.08        29.86          5.66        11.85
# 1          3.67        4.96        36.71          6.78        13.24
# 2         12.41        5.85        46.30          7.95        14.79
# 3          5.07        4.87        38.70          6.54        11.28
# 4         16.48        4.12        37.41          6.09         9.69
# ..          ...         ...          ...           ...          ...
# 391         nan         nan          nan           nan          nan
# 392         nan         nan          nan           nan          nan
# 393         nan         nan          nan           nan          nan
# 394         nan         nan          nan           nan          nan
# 395         nan         nan          nan           nan          nan
#
#      총자본경상이익률 (%)         시장규모          시총
# 0            6.81          nan 12256577.00
# 1            7.92 150470135.00 26444487.00
# 2            8.86 153315180.00 33138291.00
# 3            6.45 166693235.00 53907176.00
# 4            5.47 180679909.00 22653768.00
# ..            ...          ...         ...
# 391           nan  38500237.00         nan
# 392           nan  11866977.00         nan
# 393           nan  34293059.00         nan
# 394           nan 299877634.00         nan
# 395           nan 563907694.00         nan
#
# [396 rows x 15 columns]

# %% [markdown]
# ## 4. 데이터프레임 정리
# - Null row 없애기

# %%
msno.matrix(industry_df);

# %%
industry_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 396 entries, 0 to 395
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   산업분류          396 non-null    object
#  1   년도            396 non-null    int64
#  2   회사수 (개)       352 non-null    float64
#  3   매출액 (백만원)     352 non-null    float64
#  4   당기순이익 (백만원)   352 non-null    float64
#  5   영업이익 (백만원)    352 non-null    float64
#  6   경상이익 (백만원)    352 non-null    float64
#  7   매출액증가율 (%)    352 non-null    float64
#  8   매출액이익률 (%)    352 non-null    float64
#  9   납입자본이익률 (%)   352 non-null    float64
#  10  매출액경상이익률 (%)  352 non-null    float64
#  11  자기자본이익률 (%)   352 non-null    float64
#  12  총자본경상이익률 (%)  352 non-null    float64
#  13  시장규모          352 non-null    float64
#  14  시총            336 non-null    float64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 49.5+ KB

# %%
industry_df = industry_df.dropna()

# %%
industry_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 1 to 350
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   산업분류          294 non-null    object
#  1   년도            294 non-null    int64
#  2   회사수 (개)       294 non-null    float64
#  3   매출액 (백만원)     294 non-null    float64
#  4   당기순이익 (백만원)   294 non-null    float64
#  5   영업이익 (백만원)    294 non-null    float64
#  6   경상이익 (백만원)    294 non-null    float64
#  7   매출액증가율 (%)    294 non-null    float64
#  8   매출액이익률 (%)    294 non-null    float64
#  9   납입자본이익률 (%)   294 non-null    float64
#  10  매출액경상이익률 (%)  294 non-null    float64
#  11  자기자본이익률 (%)   294 non-null    float64
#  12  총자본경상이익률 (%)  294 non-null    float64
#  13  시장규모          294 non-null    float64
#  14  시총            294 non-null    float64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 36.8+ KB

# %% [markdown]
# - 타입 정리

# %%
industry_df['회사수 (개)'] = industry_df['회사수 (개)'].astype('int')
industry_df['매출액 (백만원)'] = industry_df['매출액 (백만원)'].astype('int')
industry_df['당기순이익 (백만원)'] = industry_df['당기순이익 (백만원)'].astype('int')
industry_df['영업이익 (백만원)'] = industry_df['영업이익 (백만원)'].astype('int')
industry_df['경상이익 (백만원)'] = industry_df['경상이익 (백만원)'].astype('int')
industry_df['시장규모'] = industry_df['시장규모'].astype('int')
industry_df['시총'] = industry_df['시총'].astype('int')
# Out:
# <ipython-input-22-ba572f1443b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry_df['회사수 (개)'] = industry_df['회사수 (개)'].astype('int')
# <ipython-input-22-ba572f1443b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry_df['매출액 (백만원)'] = industry_df['매출액 (백만원)'].astype('int')
# <ipython-input-22-ba572f1443b6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry_df['당기순이익 (백만원)'] = industry_df['당기순이익 (백만원)'].astype('int')
# <ipython-input-22-ba572f1443b6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry_df['영업이익 (백만원)'] = industry_df['영업이익 (백만원)'].astype('int')
# <ipython-input-22-ba572f1443b6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry_df['경상이익 (백만원)'] = industry_df['경상이익 (백만원)'].astype('int')
# <ipython-input-22-ba572f1443b6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry_df['시장규모'] = industry_df['시장규모'].astype('int')
# <ipython-input-22-ba572f1443b6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   industry_df['시총'] = industry_df['시총'].astype('int')

# %%
industry_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 1 to 350
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   산업분류          294 non-null    object
#  1   년도            294 non-null    int64
#  2   회사수 (개)       294 non-null    int64
#  3   매출액 (백만원)     294 non-null    int64
#  4   당기순이익 (백만원)   294 non-null    int64
#  5   영업이익 (백만원)    294 non-null    int64
#  6   경상이익 (백만원)    294 non-null    int64
#  7   매출액증가율 (%)    294 non-null    float64
#  8   매출액이익률 (%)    294 non-null    float64
#  9   납입자본이익률 (%)   294 non-null    float64
#  10  매출액경상이익률 (%)  294 non-null    float64
#  11  자기자본이익률 (%)   294 non-null    float64
#  12  총자본경상이익률 (%)  294 non-null    float64
#  13  시장규모          294 non-null    int64
#  14  시총            294 non-null    int64
# dtypes: float64(6), int64(8), object(1)
# memory usage: 36.8+ KB

# %%
msno.matrix(industry_df);

# %% [markdown]
# ## 5. 최종 dataset

# %%
industry_df['산업분류'].unique()
# Out:
# array(['건설업', '광업', '기계', '기타제조업', '농업, 임업 및 어업', '비금속광물', '서비스업', '섬유의복',
#        '운수장비', '운수창고업', '유통업', '음식료품', '의료·정밀기기', '의약품', '전기가스', '전기전자',
#        '종이·목재', '철강금속', '통신업', '화학', '제조업'], dtype=object)

# %%
industry_df['년도'].unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018])

# %%
industry_df.shape
# Out:
# (294, 15)

# %%
industry_df.to_csv('./datas/industry_merged.csv', index=False)

# %%
df = pd.read_csv('./datas/industry_merged.csv')
df.head()
# Out:
#   산업분류    년도  회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 0  건설업  2005       54   40785394      2029565     3096864     2885231
# 1  건설업  2006       57   44745972      2755247     3657870     3652228
# 2  건설업  2007       57   47834524      2802313     3566035     3718370
# 3  건설업  2008       56   53570702      3195413     3672975     4577360
# 4  건설업  2009       55   61989084      1812152     3385664     2769115
#
#    매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 0        3.67        4.96        36.71          6.78        13.24
# 1       12.41        5.85        46.30          7.95        14.79
# 2        5.07        4.87        38.70          6.54        11.28
# 3       16.48        4.12        37.41          6.09         9.69
# 4       18.77        2.27        24.91          3.40         5.77
#
#    총자본경상이익률 (%)       시장규모        시총
# 0          7.92  150470135  26444487
# 1          8.86  153315180  33138291
# 2          6.45  166693235  53907176
# 3          5.47  180679909  22653768
# 4          3.15  188031835  31828104

# %% [markdown]
# ## 6. 시총만 더함
# 2004 - 2019 년 데이터 활용 위해

# %%
industry_df_mimc = pd.merge(df_mi, df_mc, on=['산업분류','년도'], how='outer')
industry_df_mimc
# Out:
#     산업분류    년도  회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 0    건설업  2004       56   37431491      1531674     2719852     2181880
# 1    건설업  2005       54   40785394      2029565     3096864     2885231
# 2    건설업  2006       57   44745972      2755247     3657870     3652228
# 3    건설업  2007       57   47834524      2802313     3566035     3718370
# 4    건설업  2008       56   53570702      3195413     3672975     4577360
# ..   ...   ...      ...        ...          ...         ...         ...
# 347  제조업  2015     1115  791176571     37063483    44929788    46930022
# 348  제조업  2016     1162  775378712     36198535    46499201    45539207
# 349  제조업  2017     1173  755685795     43059976    53106517    53978987
# 350  제조업  2018     1214  824698749     71941760    83499912    86557629
# 351  제조업  2019     1280  834137935     29720746    43334572    40504091
#
#      매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 0         13.81        4.08        29.86          5.66        11.85
# 1          3.67        4.96        36.71          6.78        13.24
# 2         12.41        5.85        46.30          7.95        14.79
# 3          5.07        4.87        38.70          6.54        11.28
# 4         16.48        4.12        37.41          6.09         9.69
# ..          ...         ...          ...           ...          ...
# 347        2.66        4.11        43.65          5.28         4.48
# 348        3.53        5.21        54.43          6.46         4.93
# 349        5.83        3.98        50.52          5.84         4.01
# 350        3.91        4.74        56.90          6.02         4.96
# 351        2.17        2.58        27.87          4.29         2.36
#
#      총자본경상이익률 (%)            시총
# 0            6.81   12256577.00
# 1            7.92   26444487.00
# 2            8.86   33138291.00
# 3            6.45   53907176.00
# 4            5.47   22653768.00
# ..            ...           ...
# 347          3.66  825018921.00
# 348          4.25  918986848.00
# 349          3.91 1152141771.00
# 350          4.01  921986364.00
# 351          2.61 1112707421.00
#
# [352 rows x 14 columns]

# %%
msno.matrix(industry_df_mimc);

# %%
## nan 값 제거
industry_df_mimc.dropna(inplace=True)

# %%
industry_df_mimc[industry_df_mimc['산업분류'] == '제조업'].index
# Out:
# Int64Index([336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348,
#             349, 350, 351],
#            dtype='int64')

# %%
## 제조업 제거
industry_df_mimc.drop(index=industry_df_mimc[industry_df_mimc['산업분류'] == '제조업'].index, inplace=True)

# %%
industry_df_mimc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320 entries, 0 to 335
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   산업분류          320 non-null    object
#  1   년도            320 non-null    int64
#  2   회사수 (개)       320 non-null    int64
#  3   매출액 (백만원)     320 non-null    int64
#  4   당기순이익 (백만원)   320 non-null    int64
#  5   영업이익 (백만원)    320 non-null    int64
#  6   경상이익 (백만원)    320 non-null    int64
#  7   매출액증가율 (%)    320 non-null    float64
#  8   매출액이익률 (%)    320 non-null    float64
#  9   납입자본이익률 (%)   320 non-null    float64
#  10  매출액경상이익률 (%)  320 non-null    float64
#  11  자기자본이익률 (%)   320 non-null    float64
#  12  총자본경상이익률 (%)  320 non-null    float64
#  13  시총            320 non-null    float64
# dtypes: float64(7), int64(6), object(1)
# memory usage: 37.5+ KB

# %%
industry_df_mimc.to_csv('./datas/industry_merged_mimc_nomanuf.csv', index=False)

# %%
df = pd.read_csv('./datas/industry_merged_mimc_nomanuf.csv')
df.tail()
# Out:
#     산업분류    년도  회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 315   화학  2015      140  140198462      3591988     5126541     4929028
# 316   화학  2016      145  120997948      6034748     8949714     8035163
# 317   화학  2017      146  119809624      8932400    11623999    11355758
# 318   화학  2018      149  133274139      8715830    11979512    11398178
# 319   화학  2019      167  137082544      4529523     8412148     6566205
#
#      매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 315       -2.37        3.73        54.86          5.25         5.48
# 316       -2.15        5.31        75.95          7.10         7.05
# 317        4.08        4.64        83.64          6.34         6.10
# 318       12.78        5.73       103.28          7.64         7.54
# 319        0.11        3.31        57.62          5.17         3.71
#
#      총자본경상이익률 (%)           시총
# 315          4.76 151122008.00
# 316          5.88 145991288.00
# 317          5.08 174977373.00
# 318          6.38 140474961.00
# 319          3.79 161579924.00
