# %%
industry_merged = pd.read_csv('industry_merged.csv', encoding='utf-8')
industry_merged.head()
# Out:
#   산업분류    년도  회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 0  건설업  2005       54   40785394      2029565     3096864     2885231
# 1  건설업  2006       57   44745972      2755247     3657870     3652228
# 2  건설업  2007       57   47834524      2802313     3566035     3718370
# 3  건설업  2008       56   53570702      3195413     3672975     4577360
# 4  건설업  2009       55   61989084      1812152     3385664     2769115
#
#    매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 0       3.670       4.955       36.710         6.780       13.245
# 1      12.410       5.850       46.305         7.950       14.790
# 2       5.065       4.870       38.700         6.545       11.275
# 3      16.480       4.120       37.405         6.090        9.690
# 4      18.770       2.270       24.915         3.400        5.765
#
#    총자본경상이익률 (%)       시장규모        시총
# 0         7.915  150470135  26444487
# 1         8.855  153315180  33138291
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import rc
rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
mpl.rcParams['figure.figsize'] = (10, 5)

# %%
sns.lineplot(x="년도", y="시총", data=industry_merged)
plt.xticks(rotation=15)
plt.title('seaborn-matplotlib example')
plt.show()

# %%
sns.lineplot(x="년도", y="시장규모", data=industry_merged)
plt.xticks(rotation=50)
plt.title('seaborn-matplotlib example')
plt.show()

# %%
sns.lineplot(x="년도", y='매출액 (백만원)', data=industry_merged)
plt.xticks(rotation=50)
plt.title('seaborn-matplotlib example')
plt.show()

# %%
industry_merged.columns
# Out:
# Index(['산업분류', '년도', '회사수 (개)', '매출액 (백만원)', '당기순이익 (백만원)', '영업이익 (백만원)',
#        '경상이익 (백만원)', '매출액증가율 (%)', '매출액이익률 (%)', '납입자본이익률 (%)', '매출액경상이익률 (%)',
#        '자기자본이익률 (%)', '총자본경상이익률 (%)', '시장규모', '시총'],
#       dtype='object')

# %% [markdown]
# # min-max scaling

# %%
col = ['회사수 (개)', '매출액 (백만원)', '당기순이익 (백만원)', '영업이익 (백만원)',
       '경상이익 (백만원)', '매출액증가율 (%)', '매출액이익률 (%)', '납입자본이익률 (%)', 
       '매출액경상이익률 (%)', '자기자본이익률 (%)', '총자본경상이익률 (%)', '시장규모', '시총']

col_max = industry_merged[col].max()
col_min = industry_merged[col].min()

min_max_df = (industry_merged[col] - col_min) / (col_max - col_min)

min_max_df.head()
# Out:
#     회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  매출액증가율 (%)  \
# 0  0.043693   0.049443     0.068742    0.068228    0.073714    0.463918
# 1  0.046167   0.054246     0.078408    0.074729    0.082205    0.533418
# 2  0.046167   0.057991     0.079035    0.073665    0.082937    0.475011
# 3  0.045342   0.064947     0.084272    0.074904    0.092447    0.565783
# 4  0.044518   0.075155     0.065846    0.071574    0.072429    0.583993
#
#    매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  총자본경상이익률 (%)      시장규모  \
# 0    0.877981     0.574890      0.827464     0.965797      0.852300  0.068985
# 1    0.885355     0.594400      0.832323     0.981738      0.868558  0.070417
# 2    0.877281     0.578936      0.826489     0.945470      0.826963  0.077155
# 3    0.871102     0.576303      0.824599     0.929117      0.810100  0.084199
# 4    0.855860     0.550906      0.813429     0.888619      0.769889  0.087902
#
#          시총
# 0  0.022937
# 1  0.028747
# 2  0.046774
# ...

# %%
min_max_df['년도'] = industry_merged['년도']
min_max_df['산업분류'] = industry_merged['산업분류']

min_max_df.head()
# Out:
#     회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  매출액증가율 (%)  \
# 0  0.043693   0.049443     0.068742    0.068228    0.073714    0.463918
# 1  0.046167   0.054246     0.078408    0.074729    0.082205    0.533418
# 2  0.046167   0.057991     0.079035    0.073665    0.082937    0.475011
# 3  0.045342   0.064947     0.084272    0.074904    0.092447    0.565783
# 4  0.044518   0.075155     0.065846    0.071574    0.072429    0.583993
#
#    매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  총자본경상이익률 (%)      시장규모  \
# 0    0.877981     0.574890      0.827464     0.965797      0.852300  0.068985
# 1    0.885355     0.594400      0.832323     0.981738      0.868558  0.070417
# 2    0.877281     0.578936      0.826489     0.945470      0.826963  0.077155
# 3    0.871102     0.576303      0.824599     0.929117      0.810100  0.084199
# 4    0.855860     0.550906      0.813429     0.888619      0.769889  0.087902
#
#          시총    년도 산업분류
# 0  0.022937  2005  건설업
# ...

# %%
min_max_df = pd.DataFrame(min_max_df,
                   columns=['산업분류', '년도', '회사수 (개)', '매출액 (백만원)', '당기순이익 (백만원)', '영업이익 (백만원)',
                                 '경상이익 (백만원)', '매출액증가율 (%)', '매출액이익률 (%)', '납입자본이익률 (%)',
                                 '매출액경상이익률 (%)', '자기자본이익률 (%)', '총자본경상이익률 (%)', '시장규모', '시총'])
min_max_df.head()
# Out:
#   산업분류    년도   회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 0  건설업  2005  0.043693   0.049443     0.068742    0.068228    0.073714
# 1  건설업  2006  0.046167   0.054246     0.078408    0.074729    0.082205
# 2  건설업  2007  0.046167   0.057991     0.079035    0.073665    0.082937
# 3  건설업  2008  0.045342   0.064947     0.084272    0.074904    0.092447
# 4  건설업  2009  0.044518   0.075155     0.065846    0.071574    0.072429
#
#    매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 0    0.463918    0.877981     0.574890      0.827464     0.965797
# 1    0.533418    0.885355     0.594400      0.832323     0.981738
# 2    0.475011    0.877281     0.578936      0.826489     0.945470
# 3    0.565783    0.871102     0.576303      0.824599     0.929117
# 4    0.583993    0.855860     0.550906      0.813429     0.888619
#
#    총자본경상이익률 (%)      시장규모        시총
# 0      0.852300  0.068985  0.022937
# 1      0.868558  0.070417  0.028747
# ...

# %%
sns.lineplot(x="년도", y="시총", data=min_max_df)
plt.xticks(rotation=15)
plt.title('seaborn-matplotlib example')
plt.show()

# %%
sns.lineplot(x="년도", y="시장규모", data=min_max_df)
plt.xticks(rotation=15)
plt.title('seaborn-matplotlib example')
plt.show()

# %%
sns.lineplot(x="년도", y="매출액 (백만원)", data=min_max_df)
plt.xticks(rotation=15)
plt.title('seaborn-matplotlib example')
plt.show()

# %% [markdown]
# ### 표준화(StandardScaler)된 데이터로 그래프 그리기

# %%
df_norm = pd.read_csv('norm_std.csv', encoding='utf-8')
df_norm.head()
# Out:
#   산업분류    년도   회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 0  건설업  2005 -0.542403  -1.998367     0.868508    0.579365    0.852371
# 1  건설업  2006  0.881405  -1.610409     1.252618    0.972198    1.187412
# 2  건설업  2007  0.881405  -1.307870     1.277530    0.907893    1.216305
# 3  건설업  2008  0.406802  -0.745983     1.485602    0.982775    1.591530
# 4  건설업  2009 -0.067800   0.078639     0.753429    0.781592    0.801649
#
#    매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 0   -0.170437    1.187554     0.851819      1.184977     1.299236
# 1    0.927175    1.491725     1.209430      1.511661     1.501383
# 2    0.004754    1.158666     0.925987      1.119361     1.041482
# 3    1.438305    0.903774     0.877722      0.992318     0.834101
# 4    1.725894    0.275041     0.412212      0.241224     0.320557
#
#    총자본경상이익률 (%)      시장규모        시총
# 0      1.351396 -1.193173 -0.319363
# 1      1.602943 -1.121211  0.511515
# ...

# %%
df_norm.columns
# Out:
# Index(['산업분류', '년도', '회사수 (개)', '매출액 (백만원)', '당기순이익 (백만원)', '영업이익 (백만원)',
#        '경상이익 (백만원)', '매출액증가율 (%)', '매출액이익률 (%)', '납입자본이익률 (%)', '매출액경상이익률 (%)',
#        '자기자본이익률 (%)', '총자본경상이익률 (%)', '시장규모', '시총'],
#       dtype='object')

# %%
df_norm['산업분류'].unique()[0]
# Out:
# '건설업'

# %%
for i in range(len(df_norm['산업분류'].unique().tolist())):
    globals()['df_norm_ind_{}'.format(i)] = df_norm[df_norm['산업분류'] == '{}'.format(df_norm['산업분류'].unique().tolist()[i])]

df_norm_ind_20.head()
# Out:
#     산업분류    년도   회사수 (개)  매출액 (백만원)  당기순이익 (백만원)  영업이익 (백만원)  경상이익 (백만원)  \
# 280  제조업  2005 -1.458654  -1.516047    -0.270955   -0.414117   -0.215933
# 281  제조업  2006 -0.695702  -1.386625    -0.798353   -1.115239   -0.893067
# 282  제조업  2007 -0.582070  -1.447037    -1.161402   -1.470859   -1.197282
# 283  제조업  2008 -0.533371  -1.176175    -1.021275   -1.069068   -0.947613
# 284  제조업  2009 -0.906731  -0.362867    -1.300724   -0.412802   -1.345503
#
#      매출액증가율 (%)  매출액이익률 (%)  납입자본이익률 (%)  매출액경상이익률 (%)  자기자본이익률 (%)  \
# 280    0.950658    0.233111    -0.403820      0.543368     1.081940
# 281    0.090995   -0.693948    -0.777591     -0.448483    -0.200840
# 282   -0.750001   -1.513228    -1.227325     -1.281523    -1.062449
# 283    1.605389   -2.196274    -2.164795     -2.265921    -2.713198
# 284    0.603945   -0.150620    -0.466489     -0.195265     0.095048
#
#      총자본경상이익률 (%)      시장규모        시총
# 280      1.463996 -1.825190 -1.298605
# 281     -0.000707 -1.621024 -1.312625
# ...

# %%
df_norm_ind_20.columns
# Out:
# Index(['산업분류', '년도', '회사수 (개)', '매출액 (백만원)', '당기순이익 (백만원)', '영업이익 (백만원)',
#        '경상이익 (백만원)', '매출액증가율 (%)', '매출액이익률 (%)', '납입자본이익률 (%)', '매출액경상이익률 (%)',
#        '자기자본이익률 (%)', '총자본경상이익률 (%)', '시장규모', '시총'],
#       dtype='object')

# %%
df_norm['산업분류'].unique()
# Out:
# array(['건설업', '광업', '기계', '기타제조업', '농업, 임업 및 어업', '비금속광물', '서비스업', '섬유의복',
#        '운수장비', '운수창고업', '유통업', '음식료품', '의료·정밀기기', '의약품', '전기가스', '전기전자',
#        '종이·목재', '철강금속', '통신업', '화학', '제조업'], dtype=object)

# %% [markdown]
# ### 산업별 매출액, 영업이익, 시장규모, 시총, 회사 수의 변화 확인

# %%
plt.plot(df_norm_ind_0['년도'], df_norm_ind_0['매출액 (백만원)'], 'r--', 
        df_norm_ind_0['년도'], df_norm_ind_0['영업이익 (백만원)'], 'bs-', 
        df_norm_ind_0['년도'], df_norm_ind_0['시장규모'], 'g^-',
        df_norm_ind_0['년도'], df_norm_ind_0['시총'], 'k',
        df_norm_ind_0['년도'], df_norm_ind_0['회사수 (개)'], 'y--',)
plt.title('건설업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_1['년도'], df_norm_ind_1['매출액 (백만원)'], 'r--', 
          df_norm_ind_1['년도'], df_norm_ind_1['영업이익 (백만원)'], 'bs-', 
          df_norm_ind_1['년도'], df_norm_ind_1['시장규모'], 'g^-',
          df_norm_ind_1['년도'], df_norm_ind_1['시총'], 'k',
          df_norm_ind_1['년도'], df_norm_ind_1['회사수 (개)'], 'y--',)
plt.title('광업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
df_norm['산업분류'].unique()
# Out:
# array(['건설업', '광업', '기계', '기타제조업', '농업, 임업 및 어업', '비금속광물', '서비스업', '섬유의복',
#        '운수장비', '운수창고업', '유통업', '음식료품', '의료·정밀기기', '의약품', '전기가스', '전기전자',
#        '종이·목재', '철강금속', '통신업', '화학', '제조업'], dtype=object)

# %%
plt.plot(df_norm_ind_2['년도'], df_norm_ind_2['매출액 (백만원)'], 'r--', 
         df_norm_ind_2['년도'], df_norm_ind_2['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_2['년도'], df_norm_ind_2['시장규모'], 'g^-',
         df_norm_ind_2['년도'], df_norm_ind_2['시총'], 'k',
         df_norm_ind_2['년도'], df_norm_ind_2['회사수 (개)'], 'y--',)
plt.title('기계')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
df_norm['산업분류'].unique()
# Out:
# array(['건설업', '광업', '기계', '기타제조업', '농업, 임업 및 어업', '비금속광물', '서비스업', '섬유의복',
#        '운수장비', '운수창고업', '유통업', '음식료품', '의료·정밀기기', '의약품', '전기가스', '전기전자',
#        '종이·목재', '철강금속', '통신업', '화학', '제조업'], dtype=object)

# %%
plt.plot(df_norm_ind_3['년도'], df_norm_ind_3['매출액 (백만원)'], 'r--', 
         df_norm_ind_3['년도'], df_norm_ind_3['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_3['년도'], df_norm_ind_3['시장규모'], 'g^-',
         df_norm_ind_3['년도'], df_norm_ind_3['시총'], 'k',
         df_norm_ind_3['년도'], df_norm_ind_3['회사수 (개)'], 'y--',)
plt.title('기타제조업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_4['년도'], df_norm_ind_4['매출액 (백만원)'], 'r--', 
         df_norm_ind_4['년도'], df_norm_ind_4['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_4['년도'], df_norm_ind_4['시장규모'], 'g^-',
         df_norm_ind_4['년도'], df_norm_ind_4['시총'], 'k',
         df_norm_ind_4['년도'], df_norm_ind_4['회사수 (개)'], 'y--',)
plt.title('농업, 임업 및 어업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_5['년도'], df_norm_ind_5['매출액 (백만원)'], 'r--', 
         df_norm_ind_5['년도'], df_norm_ind_5['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_5['년도'], df_norm_ind_5['시장규모'], 'g^-',
         df_norm_ind_5['년도'], df_norm_ind_5['시총'], 'k',
         df_norm_ind_5['년도'], df_norm_ind_5['회사수 (개)'], 'y--',)
plt.title('비금속광물')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_6['년도'], df_norm_ind_6['매출액 (백만원)'], 'r--', 
         df_norm_ind_6['년도'], df_norm_ind_6['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_6['년도'], df_norm_ind_6['시장규모'], 'g^-',
         df_norm_ind_6['년도'], df_norm_ind_6['시총'], 'k',
         df_norm_ind_6['년도'], df_norm_ind_6['회사수 (개)'], 'y--',)
plt.title('서비스업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_7['년도'], df_norm_ind_7['매출액 (백만원)'], 'r--', 
         df_norm_ind_7['년도'], df_norm_ind_7['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_7['년도'], df_norm_ind_7['시장규모'], 'g^-',
         df_norm_ind_7['년도'], df_norm_ind_7['시총'], 'k',
         df_norm_ind_7['년도'], df_norm_ind_7['회사수 (개)'], 'y--',)
plt.title('섬유의복')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_8['년도'], df_norm_ind_8['매출액 (백만원)'], 'r--', 
         df_norm_ind_8['년도'], df_norm_ind_8['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_8['년도'], df_norm_ind_8['시장규모'], 'g^-',
         df_norm_ind_8['년도'], df_norm_ind_8['시총'], 'k',
         df_norm_ind_8['년도'], df_norm_ind_8['회사수 (개)'], 'y--',)
plt.title('운수장비')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_9['년도'], df_norm_ind_9['매출액 (백만원)'], 'r--', 
         df_norm_ind_9['년도'], df_norm_ind_9['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_9['년도'], df_norm_ind_9['시장규모'], 'g^-',
         df_norm_ind_9['년도'], df_norm_ind_9['시총'], 'k',
         df_norm_ind_9['년도'], df_norm_ind_9['회사수 (개)'], 'y--',)
plt.title('운수창고업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_10['년도'], df_norm_ind_10['매출액 (백만원)'], 'r--', 
         df_norm_ind_10['년도'], df_norm_ind_10['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_10['년도'], df_norm_ind_10['시장규모'], 'g^-',
         df_norm_ind_10['년도'], df_norm_ind_10['시총'], 'k',
         df_norm_ind_10['년도'], df_norm_ind_10['회사수 (개)'], 'y--',)
plt.title('유통업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_11['년도'], df_norm_ind_11['매출액 (백만원)'], 'r--', 
         df_norm_ind_11['년도'], df_norm_ind_11['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_11['년도'], df_norm_ind_11['시장규모'], 'g^-',
         df_norm_ind_11['년도'], df_norm_ind_11['시총'], 'k',
         df_norm_ind_11['년도'], df_norm_ind_11['회사수 (개)'], 'y--',)
plt.title('음식료품')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_12['년도'], df_norm_ind_12['매출액 (백만원)'], 'r--', 
         df_norm_ind_12['년도'], df_norm_ind_12['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_12['년도'], df_norm_ind_12['시장규모'], 'g^-',
         df_norm_ind_12['년도'], df_norm_ind_12['시총'], 'k',
         df_norm_ind_12['년도'], df_norm_ind_12['회사수 (개)'], 'y--',)
plt.title('의료·정밀기기')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_13['년도'], df_norm_ind_13['매출액 (백만원)'], 'r--', 
         df_norm_ind_13['년도'], df_norm_ind_13['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_13['년도'], df_norm_ind_13['시장규모'], 'g^-',
         df_norm_ind_13['년도'], df_norm_ind_13['시총'], 'k',
         df_norm_ind_13['년도'], df_norm_ind_13['회사수 (개)'], 'y--',)
plt.title('의약품')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_14['년도'], df_norm_ind_14['매출액 (백만원)'], 'r--', 
         df_norm_ind_14['년도'], df_norm_ind_14['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_14['년도'], df_norm_ind_14['시장규모'], 'g^-',
         df_norm_ind_14['년도'], df_norm_ind_14['시총'], 'k',
         df_norm_ind_14['년도'], df_norm_ind_14['회사수 (개)'], 'y--',)
plt.title('전기가스')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_15['년도'], df_norm_ind_15['매출액 (백만원)'], 'r--', 
         df_norm_ind_15['년도'], df_norm_ind_15['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_15['년도'], df_norm_ind_15['시장규모'], 'g^-',
         df_norm_ind_15['년도'], df_norm_ind_15['시총'], 'k',
         df_norm_ind_15['년도'], df_norm_ind_15['회사수 (개)'], 'y--',)
plt.title('전기전자')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_16['년도'], df_norm_ind_16['매출액 (백만원)'], 'r--', 
         df_norm_ind_16['년도'], df_norm_ind_16['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_16['년도'], df_norm_ind_16['시장규모'], 'g^-',
         df_norm_ind_16['년도'], df_norm_ind_16['시총'], 'k',
         df_norm_ind_16['년도'], df_norm_ind_16['회사수 (개)'], 'y--',)
plt.title('종이·목재')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_17['년도'], df_norm_ind_17['매출액 (백만원)'], 'r--', 
         df_norm_ind_17['년도'], df_norm_ind_17['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_17['년도'], df_norm_ind_17['시장규모'], 'g^-',
         df_norm_ind_17['년도'], df_norm_ind_17['시총'], 'k',
         df_norm_ind_17['년도'], df_norm_ind_17['회사수 (개)'], 'y--',)
plt.title('철강금속')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_18['년도'], df_norm_ind_18['매출액 (백만원)'], 'r--', 
         df_norm_ind_18['년도'], df_norm_ind_18['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_18['년도'], df_norm_ind_18['시장규모'], 'g^-',
         df_norm_ind_18['년도'], df_norm_ind_18['시총'], 'k',
         df_norm_ind_18['년도'], df_norm_ind_18['회사수 (개)'], 'y--',)
plt.title('통신업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_19['년도'], df_norm_ind_19['매출액 (백만원)'], 'r--', 
         df_norm_ind_19['년도'], df_norm_ind_19['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_19['년도'], df_norm_ind_19['시장규모'], 'g^-',
         df_norm_ind_19['년도'], df_norm_ind_19['시총'], 'k',
         df_norm_ind_19['년도'], df_norm_ind_19['회사수 (개)'], 'y--',)
plt.title('화학')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()

# %%
plt.plot(df_norm_ind_20['년도'], df_norm_ind_20['매출액 (백만원)'], 'r--', 
         df_norm_ind_20['년도'], df_norm_ind_20['영업이익 (백만원)'], 'bs-', 
         df_norm_ind_20['년도'], df_norm_ind_20['시장규모'], 'g^-',
         df_norm_ind_20['년도'], df_norm_ind_20['시총'], 'k',
         df_norm_ind_20['년도'], df_norm_ind_20['회사수 (개)'], 'y--',)
plt.title('제조업')
plt.legend(['매출액 (백만원)', '영업이익 (백만원)', '시장규모', '시총', '회사수 (개)'])
plt.show()
